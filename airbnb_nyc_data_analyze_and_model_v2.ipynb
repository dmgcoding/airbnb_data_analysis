# %% [markdown]
# # Airbnb
#
# Dataset I used describes the listing activity and metrics in NYC, NY for 2019.
#
# Dataset link > https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data
#
# ## End Goal/Purpose
# Main Goal is to analyze data to see the what kind of listings people used most, what locations/neighborhoods are the most expensive, how parameters like availability or minmum nights affect the the price.
#
# ## Analyzing, Visualizing and Cleaning data
# Here we
# analyze data, visualize, see correlations,decide what column do we need and what we don't need, remove unrelated columns, look for the null/na values or wrong data, treat those data, check outliers, treat the outliers and see if it needs more cleaning.
#
# ## Preprocessing
# Preprocessing data to feed the model, split data for training, evaluating and testing
#
# ## Model
# build the model.
#
# ## evaluate and test the efficiency
# evaluate the model's efficiency and test the data with test dataset manually.
#
# ## report
# create a report of data and model input shapes, etc.

# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
keras = tf.keras

# %% [markdown]
# ### load data

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1gZub5RlOFHcEuyamGmKdg0SYOIViyspW')

# %% [markdown]
# ## Analyze, visualize data

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# We have 48895 rows and 16 columns in the dataset.
#
# As you can see from the output there are some null values.

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-5-6dc1c4c1753e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %% [markdown]
# I don't see any significant direct corrleations between parameters. We can see reviews_per_month and number_of_reviews have 0.5 correlation. That is straightforward but all of the other values are very low.

# %% [markdown]
# One property can have one hostname, one hostname can have multiple properties. Let's see how many properties one hostname own average(mean)

# %%
host_names = df['host_name'].unique()
host_name_owned_properties_mean = len(df.index) / len(host_names)
print("there are ",len(host_names), "unique hostnames. One hostname owns averagely ",host_name_owned_properties_mean, " properties.")
# Out:
# there are  11453 unique hostnames. One hostname owns averagely  4.2691871125469305  properties.

# %% [markdown]
# there are  11453 unique hostnames. One hostname owns averagely  4.2691871125469305  properties.

# %% [markdown]
# There are 5 neighbourhood groups.

# %%
len(df['neighbourhood_group'].unique())
# Out:
# 5

# %% [markdown]
# Let's see what neighbourhood group is the most expensive.

# %%
sns.set_theme(style='ticks',palette='pastel')

# %%
sns.barplot(data=df,x='neighbourhood_group',y='price')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# Average price of properties is highest in Manhattan and lowest in Bronx.
#
# Let's see the room type.

# %%
sns.barplot(data=df,x='neighbourhood_group',y='price',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# Entire home/apt are more expensive in any neighbourhood group.

# %%
sns.scatterplot(data=df,x='longitude',y='latitude',hue='neighbourhood_group')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# What is the most favorite room type.

# %%
sns.displot(data=df,x='room_type')

# %% [markdown]
# Entire home/apt is the most favorite and shared is the least favorite.

# %%
sns.barplot(df,x='room_type',y='price')
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.barplot(df,x='availability_365',y='price')
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
sns.barplot(df,x='number_of_reviews',y='price')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %% [markdown]
# Now let's see the price distribution

# %%
sns.boxplot(df,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
print('highest value for price is ',df['price'].max(), ". cheapest one is ",df['price'].min())
print('price mean/average is ',df['price'].mean(), "mode is ",df['price'].mode(),"median is ",df['price'].median())
print('standard deviation is ', df['price'].std())
# Out:
# highest value for price is  10000 . cheapest one is  0
# price mean/average is  152.7206871868289 mode is  0    100
# Name: price, dtype: int64 median is  106.0
# standard deviation is  240.15416974718758

# %% [markdown]
# Dots are the outliers.

# %% [markdown]
# highest value for price is  10000 . cheapest one is  0
# price mean/average is  152.7206871868289 mode is  0    100
# Name: price, dtype: int64 median is  106.0
# standard deviation is  240.15416974718758

# %%
sns.displot(df,x='price',kde=True)

# %%
print("in price distribution skew is ",df['price'].skew(), ". kurtosis is ",df['price'].kurtosis())
# Out:
# in price distribution skew is  19.118938995046033 . kurtosis is  585.6728788988286

# %% [markdown]
# in price distribution skew is  19.118938995046033 . kurtosis is  585.6728788988286
#
# skew and kurtosis is very high. high skew mean data is not evenly distributed. high kurtosis means there's lot of outliers.
#
# If we look closely we can see average rental price is 152$ but there are some unusual prices like 10000. This may be caused by wrong entry data, data processing errors, and natural variances.
#
# *wrong entry data is very straightforward. this means error in entering data.
#
# *data processing errors can happen in the process of data modeling and manipulation after collecting data.
#
# *natural variances are the anormalies in real world situations. as a example if we are analyzing exam marks data in a class/school some students may get high marks wheather the exam is hard or easy. They are anormalies.
#
# We can trim, cap, or use other methods or in cases like fraud detection these outliers are used to detect fraud.

# %% [markdown]
# ## Cleaning data
#
# 1.remove unrelated columns
#
# 2.check and remove duplicates
#
# 3.check for null values and treat them
#
# 4.treat outliers

# %% [markdown]
# ### remove unnecessary columns

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# id- id doesn't affect the price. That's clear. we can remove that.
#
# name- doesn't affect the price.
#
# host_id - doesn't affect the price.
#
# host_name - doesn't affect the price.
#
# last_review - doesn't affect the price.
#
# last_review - doesn't affect the price.
#
# reviews_per_month - doesn't affect the price.
#
# calculated_host_listings_count - doesn't affect the price.

# %%
dfc = df.drop(columns=['id','name','host_id','host_name','last_review','reviews_per_month','calculated_host_listings_count','latitude','longitude'])
dfc.head()
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room    149               1
# 1           Manhattan       Midtown  Entire home/apt    225               1
# 2           Manhattan        Harlem     Private room    150               3
# 3            Brooklyn  Clinton Hill  Entire home/apt     89               1
# 4           Manhattan   East Harlem  Entire home/apt     80              10
#
#    number_of_reviews  availability_365
# 0                  9               365
# 1                 45               355
# 2                  0               365
# 3                270               194
# 4                  9                 0

# %% [markdown]
# Removed these 'id','name','host_id','host_name','last_review','reviews_per_month','calculated_host_listings_count','latitude','longitude' columns

# %% [markdown]
# ### Check and remove duplicates

# %%
dfc.duplicated().values.any()
# Out:
# True

# %% [markdown]
# No duplicates in the dataset.

# %% [markdown]
# ### Wrong data clean

# %%
dfc.isnull().values.any()
# Out:
# False

# %%
dfc.isna().values.any()
# Out:
# False

# %% [markdown]
# No invalid inputs to clean.

# %% [markdown]
# ### treat outliers

# %%
price_skew_before = dfc['price'].skew()
price_kurtosis_before = dfc['price'].kurtosis()

# make a copy of dataset
new_df = dfc.copy()

p25 = new_df['price'].quantile(0.25)
p75 = new_df['price'].quantile(0.75)
iqr = p75 - p25

# limits
price_lower_limit = p25 - 1.5 * iqr
price_upper_limit = p75 + 1.5 * iqr

# price lower limit is a negative value. we will set it to 0
price_lower_limit = 0

# get trimmed dataset
new_df = new_df[new_df['price'] > price_upper_limit]
new_df.shape
# Out:
# (2972, 7)

# %% [markdown]
# There's 2972 records of dataset. We can either remove them or cap them. In this case we will set the values above the upper limit to upper limit.

# %% [markdown]
# Let's see the boxplot of before cleaning and after cleaning price column.(left and right)

# %%
df_cap = dfc.copy()

df_cap['price'] = np.where(
    df_cap['price'] < price_lower_limit,
    price_lower_limit,
    np.where(
        df_cap['price'] > price_upper_limit,
        price_upper_limit,
        df_cap['price']
    )
)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.boxplot(dfc,x='price')
plt.subplot(1,2,2)
sns.boxplot(df_cap,x='price')
plt.show()

# %% [markdown]
# Let's see the skew and kurtosis values before and after.

# %%
print("before skew is ",dfc['price'].skew(), "after cleaning outliers skew is ",df_cap['price'].skew())
print("before kurtosis is ",dfc['price'].kurtosis(), "after cleaning outliers kurtosis is ",df_cap['price'].kurtosis())
# Out:
# before skew is  19.118938995046033 after cleaning outliers skew is  1.0227703235026613
# before kurtosis is  585.6728788988286 after cleaning outliers kurtosis is  0.15710037427136436

# %% [markdown]
# before skew is  19.118938995046033 after cleaning outliers skew is  1.0227703235026613
# before kurtosis is  585.6728788988286 after cleaning outliers kurtosis is  0.15710037427136436

# %%
sns.displot(df_cap,x='price',kde=True)

# %%
sns.displot(df_cap,x='minimum_nights',kde=True)

# %%
sns.boxplot(df_cap,x='minimum_nights')
# Out:
# <Axes: xlabel='minimum_nights'>

# %%
price_skew_before = df_cap['minimum_nights'].skew()
price_kurtosis_before = df_cap['minimum_nights'].kurtosis()

# make a copy of dataset
new_df = df_cap.copy()

p25 = new_df['minimum_nights'].quantile(0.25)
p75 = new_df['minimum_nights'].quantile(0.75)
iqr = p75 - p25

# limits
minimum_nights_lower_limit = p25 - 1.5 * iqr
minimum_nights_upper_limit = p75 + 1.5 * iqr
print(minimum_nights_lower_limit)
print(minimum_nights_upper_limit)

# price lower limit is a negative value. we will set it to 0
minimum_nights_lower_limit = 0

# get trimmed dataset
new_df = new_df[new_df['minimum_nights'] > minimum_nights_upper_limit]
new_df.shape
# Out:
# -5.0
# 11.0
# (6607, 7)

# %% [markdown]
# 6607 records to clean.

# %%
df_cap2 = df_cap.copy()

df_cap2['minimum_nights'] = np.where(
    df_cap2['minimum_nights'] < minimum_nights_lower_limit,
    minimum_nights_lower_limit,
    np.where(
        df_cap2['minimum_nights'] > minimum_nights_upper_limit,
        minimum_nights_upper_limit,
        df_cap2['minimum_nights']
    )
)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.boxplot(new_df,x='minimum_nights')
plt.subplot(1,2,2)
sns.boxplot(df_cap2,x='minimum_nights')
plt.show()

# %%
sns.displot(df_cap2,x='minimum_nights',kde=True)

# %%
print("before skew is ",new_df['minimum_nights'].skew(), "after cleaning outliers skew is ",df_cap2['minimum_nights'].skew())
print("before kurtosis is ",new_df['minimum_nights'].kurtosis(), "after cleaning outliers kurtosis is ",df_cap2['minimum_nights'].kurtosis())
# Out:
# before skew is  11.4976641089728 after cleaning outliers skew is  1.2861165892722501
# before kurtosis is  198.70526071433 after cleaning outliers kurtosis is  0.29168099518225254

# %%
sns.displot(df_cap2,x='number_of_reviews',kde=True)

# %%
sns.boxplot(df_cap2,x='number_of_reviews')
# Out:
# <Axes: xlabel='number_of_reviews'>

# %%
number_of_reviews_skew_before = df_cap2['number_of_reviews'].skew()
number_of_reviews_kurtosis_before = df_cap2['number_of_reviews'].kurtosis()

# make a copy of dataset
new_df = df_cap2.copy()

p25 = new_df['number_of_reviews'].quantile(0.25)
p75 = new_df['number_of_reviews'].quantile(0.75)
iqr = p75 - p25

# limits
number_of_reviews_lower_limit = p25 - 1.5 * iqr
number_of_reviews_upper_limit = p75 + 1.5 * iqr
print(number_of_reviews_lower_limit)
print(number_of_reviews_upper_limit)

# price lower limit is a negative value. we will set it to 0
number_of_reviews_lower_limit = 0

# get trimmed dataset
new_df = new_df[new_df['number_of_reviews'] > number_of_reviews_upper_limit]
new_df.shape
# Out:
# -33.5
# 58.5
# (6021, 7)

# %%
df_cap3 = df_cap2.copy()

df_cap3['number_of_reviews'] = np.where(
    df_cap3['number_of_reviews'] < number_of_reviews_lower_limit,
    number_of_reviews_lower_limit,
    np.where(
        df_cap3['number_of_reviews'] > number_of_reviews_upper_limit,
        number_of_reviews_upper_limit,
        df_cap3['number_of_reviews']
    )
)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.boxplot(new_df,x='number_of_reviews')
plt.subplot(1,2,2)
sns.boxplot(df_cap3,x='number_of_reviews')
plt.show()

# %%
sns.displot(df_cap3,x='number_of_reviews',kde=True)

# %%
print("before skew is ",new_df['number_of_reviews'].skew(), "after cleaning outliers skew is ",df_cap3['number_of_reviews'].skew())
print("before kurtosis is ",new_df['number_of_reviews'].kurtosis(), "after cleaning outliers kurtosis is ",df_cap3['number_of_reviews'].kurtosis())
# Out:
# before skew is  2.1801820314289766 after cleaning outliers skew is  1.2289740130905138
# before kurtosis is  7.22432220658791 after cleaning outliers kurtosis is  -0.017516202928665514

# %%
sns.displot(df_cap3,x='availability_365',kde=True)

# %%
sns.boxplot(df_cap3,x='availability_365')
# Out:
# <Axes: xlabel='availability_365'>

# %%
print(df_cap3['availability_365'].min())

print(df_cap3['availability_365'].max())

print(df_cap3['availability_365'].mean())

print(df_cap3['availability_365'].skew())

print(df_cap3['availability_365'].kurtosis())
# Out:
# 0
# 365
# 112.78132733408324
# 0.7634075771134318
# -0.9975340452460988

# %% [markdown]
# Nothing to clean in availablity_365

# %% [markdown]
# ## Preprocessing
# Preprocessing data to feed the model, split data for training, evaluating and testing
#
# 1. encode categorical data
# 2. split dataset

# %% [markdown]
# There are 3 categorical columns. neighborhood_group, neighborhood and room_type. We can use one hot encoding or label encoding. in this case I will use label encoding. Because there's too much categories in columns like neighborhood. encoding as labels can affect the model's efficiency if they get interpreted as those integer labels have ordinal relationship.

# %%
df_cap3.head()
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room  149.0             1.0
# 1           Manhattan       Midtown  Entire home/apt  225.0             1.0
# 2           Manhattan        Harlem     Private room  150.0             3.0
# 3            Brooklyn  Clinton Hill  Entire home/apt   89.0             1.0
# 4           Manhattan   East Harlem  Entire home/apt   80.0            10.0
#
#    number_of_reviews  availability_365
# 0                9.0               365
# 1               45.0               355
# 2                0.0               365
# 3               58.5               194
# 4                9.0                 0

# %%
import json

# encode categorical data to labels

room_type_key = 1
neighbourhood_group_key = 1
neighbourhood_key = 1

def encode_room_types_dict(room_types):
  global room_type_key
  encoded_dict = {}
  for room_type in room_types:
    if room_type not in encoded_dict:
      encoded_dict[room_type] = room_type_key
      room_type_key += 1
  return encoded_dict

def encode_neighbourhood_groups_dict(room_types):
  global neighbourhood_group_key
  encoded_dict = {}
  for room_type in room_types:
    if room_type not in encoded_dict:
      encoded_dict[room_type] = neighbourhood_group_key
      neighbourhood_group_key += 1
  return encoded_dict

def encode_neighbourhoods_dict(room_types):
  global neighbourhood_key
  encoded_dict = {}
  for room_type in room_types:
    if room_type not in encoded_dict:
      encoded_dict[room_type] = neighbourhood_key
      neighbourhood_key += 1
  return encoded_dict

encoded_room_type_dict = encode_room_types_dict(df_cap3['room_type'])
encoded_neighbourhood_groups_dict = encode_neighbourhood_groups_dict(df_cap3['neighbourhood_group'])
encoded_neighbourhoods_dict = encode_neighbourhoods_dict(df_cap3['neighbourhood'])

# save the encoded dicts as a json files
with open('encoded_room_type_dict.json', "w") as json_file:
    json.dump(encoded_room_type_dict, json_file)

with open('encoded_neighbourhood_groups_dict.json', "w") as json_file:
    json.dump(encoded_neighbourhood_groups_dict, json_file)

with open('encoded_neighbourhoods_dict.json', "w") as json_file:
    json.dump(encoded_neighbourhoods_dict, json_file)

# %% [markdown]
# functions for encode categorical data. label encode the categorical data.

# %%
def encode_room_types(df):
  for i in df.index:
    if df.loc[i, "room_type"] in encoded_room_type_dict:
      df.loc[i,"room_type"] = encoded_room_type_dict[df.loc[i, "room_type"]]
    else:
      df.loc[i,"room_type"] = 0

def encode_neighbourhood_groups(df):
  for i in df.index:
    if df.loc[i, "neighbourhood_group"] in encoded_neighbourhood_groups_dict:
      df.loc[i,"neighbourhood_group"] = encoded_neighbourhood_groups_dict[df.loc[i, "neighbourhood_group"]]
    else:
      df.loc[i,"neighbourhood_group"] = 0

def encode_neighbourhoods(df):
  for i in df.index:
    if df.loc[i, "neighbourhood"] in encoded_neighbourhoods_dict:
      df.loc[i,"neighbourhood"] = encoded_neighbourhoods_dict[df.loc[i, "neighbourhood"]]
    else:
      df.loc[i,"neighbourhood"] = 0

dfc2 = df_cap3.copy()
encode_room_types(dfc2)
encode_neighbourhood_groups(dfc2)
encode_neighbourhoods(dfc2)
dfc2.head()
# Out:
#   neighbourhood_group neighbourhood room_type  price  minimum_nights  \
# 0                   1             1         1  149.0             1.0
# 1                   2             2         2  225.0             1.0
# 2                   2             3         1  150.0             3.0
# 3                   1             4         2   89.0             1.0
# 4                   2             5         2   80.0            10.0
#
#    number_of_reviews  availability_365
# 0                9.0               365
# 1               45.0               355
# 2                0.0               365
# 3               58.5               194
# 4                9.0                 0

# %% [markdown]
# Splitting the dataset

# %%
# training,eval,test
total_rows = len(dfc2.index)

rows_p_70 = round(total_rows * 0.8)
rows_p_90 = round(total_rows * 0.95)
rows_p_10 = round(total_rows * 0.05)

training_features = dfc2[:rows_p_70]
eval_features = dfc2[rows_p_70:rows_p_90]
test_features = dfc2[rows_p_90:]

# %%
print("training df",len(training_features.index), "\n eval df", len(eval_features.index), "\n test df",len(test_features.index))
# Out:
# training df 39116
#  eval df 7334
#  test df 2445

# %% [markdown]
# Now let's split labels and features

# %%
training_labels = training_features.pop('price')
eval_labels = eval_features.pop('price')
test_labels = test_features.pop('price')

# %%
training_features.to_csv('training_features.csv', index=False)

# %%
training_features.head()
# Out:
#   neighbourhood_group neighbourhood room_type  minimum_nights  \
# 0                   1             1         1             1.0
# 1                   2             2         2             1.0
# 2                   2             3         1             3.0
# 3                   1             4         2             1.0
# 4                   2             5         2            10.0
#
#    number_of_reviews  availability_365
# 0                9.0               365
# 1               45.0               355
# 2                0.0               365
# 3               58.5               194
# 4                9.0                 0

# %%
training_labels.skew()
# Out:
# 1.074107186187569

# %% [markdown]
# finaly convert int values to float32

# %%
training_features = np.asarray(training_features).astype('float32')
eval_features = np.asarray(eval_features).astype('float32')
test_features = np.asarray(test_features).astype('float32')
training_labels = np.asarray(training_labels).astype('float32')
eval_labels = np.asarray(eval_labels).astype('float32')
test_labels = np.asarray(test_labels).astype('float32')

# %%
training_features.shape
# Out:
# (39116, 6)

# %% [markdown]
# ## Model

# %%
normalizer_layer = keras.layers.Normalization()
normalizer_layer.adapt(training_features)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(6,)),
    normalizer_layer,
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(1)
])

model.compile(loss='mean_absolute_error',optimizer='adam' ,metrics=[keras.metrics.MeanAbsoluteError()],)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 6)                 0
#
#  normalization_1 (Normalizat  (None, 6)                13
#  ion)
#
#  dense_6 (Dense)             (None, 64)                448
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,686
# Trainable params: 4,673
# Non-trainable params: 13
# _________________________________________________________________

# %%
epochs = 500
verbose = 0

# fitting can take some time. This will print a dots while training so we can see code is running.
class PrintDotCallback(tf.keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        print(".", end='', flush=True)  # Print a dot without newline

# patience is in epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

history = model.fit(training_features,training_labels,epochs=epochs,verbose=verbose,callbacks=[early_stopping,PrintDotCallback()])
# Out:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...

# %%
history.history['loss'][-1]
# Out:
# 39.8888053894043

# %% [markdown]
# loss is 39.71485900878906 after 500 epochs.

# %%
plt.plot(history.history['loss'])
plt.xLabel='epoch'
plt.yLabel='loss'
plt.show()

# %% [markdown]
# Notice that it didn't run 1000 epochs. That's because of the early_stoping function. What it does is it will stop if the fitting/training if the loss starts to go up. It will stop overfitting. In this case in around 300 epochs it is fully trained. If we do more epochs than that loss can start to increase.

# %%
eval = model.evaluate(eval_features,eval_labels)
eval
# Out:
# 230/230 [==============================] - 0s 1ms/step - loss: 43.9011 - mean_absolute_error: 43.9011
# [43.901100158691406, 43.901100158691406]

# %%
model.save('airbnb_nyc_room_price_predict_model.h5')

# %%
model = keras.models.load_model('airbnb_nyc_room_price_predict_model.h5')

# %%
index = 100
preds = model.predict([test_features[index]])
pred_price = preds[0][-1]
actual_price = test_labels[index]
print("predicted price is",pred_price,"\nactual price is",actual_price)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# predicted price is 123.226494
# actual price is 125.0

# %% [markdown]
# Model's accuracy is not consistent. ongoing...

# %% [markdown]
# # ongoing...
